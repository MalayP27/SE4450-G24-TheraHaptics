# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, TimeDistributed
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load and merge datasets
file_paths = {
    "thumbup": "../Data_Extracting/emg_training_data_thumbup_time_series.csv",
    "fist": "../Data_Extracting/emg_training_data_fist_time_series.csv",
}

data_frames = []
for gesture, path in file_paths.items():
    df = pd.read_csv(path)
    df["gesture"] = gesture
    data_frames.append(df)

data = pd.concat(data_frames, ignore_index=True)

# Extract features and labels
X = data.iloc[:, :-1].values  # Exclude the label column
y = data.iloc[:, -1].values   # Label column

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Normalize data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Reshape for LSTM and CNN+LSTM (samples, time_steps=50, features=6)
X_reshaped = X_scaled.reshape(len(X_scaled), 50, 6)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y_encoded, test_size=0.2, random_state=42)

# %%
# LSTM Model
lstm_model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(50, 6)),
    LSTM(64, return_sequences=False),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(len(label_encoder.classes_), activation='softmax')
])

lstm_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train LSTM
history_lstm = lstm_model.fit(X_train, y_train, epochs=50, batch_size=8, validation_data=(X_test, y_test))

# Evaluate LSTM
y_lstm_pred = np.argmax(lstm_model.predict(X_test), axis=1)
print(f"LSTM Accuracy: {accuracy_score(y_test, y_lstm_pred):.4f}")
print(classification_report(y_test, y_lstm_pred, target_names=label_encoder.classes_))
# Out:
# C:\Users\Rohan Datta\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.5993 - loss: 0.6535 - val_accuracy: 0.5814 - val_loss: 0.4835
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7225 - loss: 0.4238 - val_accuracy: 0.9302 - val_loss: 0.1441
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.6866 - loss: 1.0313 - val_accuracy: 0.6279 - val_loss: 0.6684
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5351 - loss: 0.7423 - val_accuracy: 0.6279 - val_loss: 0.6712
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5625 - loss: 0.6987 - val_accuracy: 0.6279 - val_loss: 0.6719
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5453 - loss: 0.6958 - val_accuracy: 0.5581 - val_loss: 0.6860
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5760 - loss: 0.6820 - val_accuracy: 0.6279 - val_loss: 0.6625
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5213 - loss: 0.6929 - val_accuracy: 0.9302 - val_loss: 0.5798
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8447 - loss: 0.5319 - val_accuracy: 0.7442 - val_loss: 0.5376
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5922 - loss: 0.7330 - val_accuracy: 0.8605 - val_loss: 0.4363
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5801 - loss: 0.6841 - val_accuracy: 0.9302 - val_loss: 0.3113
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6685 - loss: 0.6408 - val_accuracy: 0.4419 - val_loss: 0.7233
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.4963 - loss: 0.6944 - val_accuracy: 0.6279 - val_loss: 0.6637
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5331 - loss: 0.6959 - val_accuracy: 0.6279 - val_loss: 0.6683
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5343 - loss: 0.7007 - val_accuracy: 0.6279 - val_loss: 0.6728
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6121 - loss: 0.6731 - val_accuracy: 0.6279 - val_loss: 0.6504
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5306 - loss: 0.6715 - val_accuracy: 0.9302 - val_loss: 0.5856
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8804 - loss: 0.4894 - val_accuracy: 0.9302 - val_loss: 0.2374
# Epoch 19/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7351 - loss: 0.4914 - val_accuracy: 0.6512 - val_loss: 0.6650
# Epoch 20/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.6156 - loss: 0.6389 - val_accuracy: 0.6279 - val_loss: 0.6674
# Epoch 21/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5689 - loss: 0.6780 - val_accuracy: 0.6279 - val_loss: 0.6675
# Epoch 22/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5686 - loss: 0.6726 - val_accuracy: 0.6279 - val_loss: 0.6779
# Epoch 23/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5102 - loss: 0.6747 - val_accuracy: 0.6279 - val_loss: 0.6734
# Epoch 24/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5005 - loss: 0.6808 - val_accuracy: 0.6279 - val_loss: 0.6782
# Epoch 25/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5754 - loss: 0.6782 - val_accuracy: 0.6279 - val_loss: 0.6780
# Epoch 26/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5575 - loss: 0.6751 - val_accuracy: 0.6279 - val_loss: 0.6650
# Epoch 27/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.4543 - loss: 0.6964 - val_accuracy: 0.6279 - val_loss: 0.6793
# Epoch 28/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.4867 - loss: 0.6731 - val_accuracy: 0.6279 - val_loss: 0.6773
# Epoch 29/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.4784 - loss: 0.6814 - val_accuracy: 0.6279 - val_loss: 0.6739
# Epoch 30/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5431 - loss: 0.6805 - val_accuracy: 0.6279 - val_loss: 0.6655
# Epoch 31/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.5701 - loss: 0.6734 - val_accuracy: 0.6279 - val_loss: 0.6803
# Epoch 32/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.4698 - loss: 0.6920 - val_accuracy: 0.4419 - val_loss: 0.6898
# Epoch 33/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.4652 - loss: 0.6835 - val_accuracy: 0.6279 - val_loss: 0.6742
# Epoch 34/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5726 - loss: 0.6722 - val_accuracy: 0.6279 - val_loss: 0.6723
# Epoch 35/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5727 - loss: 0.6774 - val_accuracy: 0.6279 - val_loss: 0.6774
# Epoch 36/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5874 - loss: 0.6868 - val_accuracy: 0.6279 - val_loss: 0.6747
# Epoch 37/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5522 - loss: 0.6792 - val_accuracy: 0.6279 - val_loss: 0.6680
# Epoch 38/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5788 - loss: 0.6643 - val_accuracy: 0.7209 - val_loss: 0.6410
# Epoch 39/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7344 - loss: 0.6279 - val_accuracy: 0.5581 - val_loss: 0.6717
# Epoch 40/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6543 - loss: 0.6268 - val_accuracy: 0.7907 - val_loss: 0.5532
# Epoch 41/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.6773 - loss: 0.6218 - val_accuracy: 0.7674 - val_loss: 0.5211
# Epoch 42/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8702 - loss: 0.3758 - val_accuracy: 0.9302 - val_loss: 0.1713
# Epoch 43/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6553 - loss: 0.8850 - val_accuracy: 0.6279 - val_loss: 0.6677
# Epoch 44/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5453 - loss: 0.6675 - val_accuracy: 0.6744 - val_loss: 0.6810
# Epoch 45/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5075 - loss: 0.6964 - val_accuracy: 0.6279 - val_loss: 0.6618
# Epoch 46/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5331 - loss: 0.6939 - val_accuracy: 0.6279 - val_loss: 0.6643
# Epoch 47/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5513 - loss: 0.6625 - val_accuracy: 0.6279 - val_loss: 0.6616
# Epoch 48/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5436 - loss: 0.6951 - val_accuracy: 0.6977 - val_loss: 0.6518
# Epoch 49/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6552 - loss: 0.6554 - val_accuracy: 0.6279 - val_loss: 0.6154
# Epoch 50/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7183 - loss: 0.6161 - val_accuracy: 0.9302 - val_loss: 0.5393
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step
# LSTM Accuracy: 0.9302
#               precision    recall  f1-score   support
#
#         fist       1.00      0.88      0.93        24
#      thumbup       0.86      1.00      0.93        19
#
#     accuracy                           0.93        43
#    macro avg       0.93      0.94      0.93        43
# weighted avg       0.94      0.93      0.93        43

# %%
# CNN + LSTM Hybrid Model
hybrid_model = Sequential([
    TimeDistributed(Conv1D(64, kernel_size=3, activation='relu'), input_shape=(50, 6, 1)),
    TimeDistributed(MaxPooling1D(pool_size=2)),
    TimeDistributed(Flatten()),
    
    LSTM(64, return_sequences=False),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(len(label_encoder.classes_), activation='softmax')
])

hybrid_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train Hybrid Model
history_hybrid = hybrid_model.fit(X_train, y_train, epochs=50, batch_size=8, validation_data=(X_test, y_test))

# Evaluate Hybrid Model
y_hybrid_pred = np.argmax(hybrid_model.predict(X_test), axis=1)
print(f"CNN+LSTM Accuracy: {accuracy_score(y_test, y_hybrid_pred):.4f}")
print(classification_report(y_test, y_hybrid_pred, target_names=label_encoder.classes_))
# Out:
# Epoch 1/50
# C:\Users\Rohan Datta\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - accuracy: 0.4288 - loss: 0.7124 - val_accuracy: 0.6279 - val_loss: 0.6174
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5149 - loss: 0.6508 - val_accuracy: 0.7907 - val_loss: 0.4406
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8317 - loss: 0.4559 - val_accuracy: 0.6279 - val_loss: 1.5638
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5895 - loss: 1.0549 - val_accuracy: 0.4419 - val_loss: 0.7682
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5454 - loss: 0.7404 - val_accuracy: 0.6279 - val_loss: 0.6461
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.5790 - loss: 0.6879 - val_accuracy: 0.8140 - val_loss: 0.6291
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.6510 - loss: 0.6254 - val_accuracy: 0.8372 - val_loss: 0.5248
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6401 - loss: 0.6362 - val_accuracy: 0.9302 - val_loss: 0.4151
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8384 - loss: 0.4554 - val_accuracy: 0.9302 - val_loss: 0.2848
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8815 - loss: 0.3153 - val_accuracy: 0.9302 - val_loss: 0.1927
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.